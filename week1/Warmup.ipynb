# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
vector_x = np.linspace(-5, 5)
vector_y = np.sin(vector_x)

vector_add = vector_x + vector_y

# %%
plt.plot(vector_x, vector_y)
plt.show()
